# %%
import pandas as pd

# %%
df = pd.read_csv('../GlobalLandTemperaturesByCity.csv')
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
del df['AverageTemperatureUncertainty']
df.head()
# Out:
#            dt  AverageTemperature   City  Country Latitude Longitude
# 0  1743-11-01               6.068  Århus  Denmark   57.05N    10.33E
# 1  1743-12-01                 NaN  Århus  Denmark   57.05N    10.33E
# 2  1744-01-01                 NaN  Århus  Denmark   57.05N    10.33E
# 3  1744-02-01                 NaN  Århus  Denmark   57.05N    10.33E
# 4  1744-03-01                 NaN  Århus  Denmark   57.05N    10.33E

# %%
df['Year'] = df['dt'].map(lambda dt: dt.split('-')[0])
df['Month'] = df['dt'].map(lambda dt: dt.split('-')[1])
del df['dt']

# %%
df.head()
# Out:
#    AverageTemperature   City  Country Latitude Longitude  Year Month
# 0               6.068  Århus  Denmark   57.05N    10.33E  1743    11
# 1                 NaN  Århus  Denmark   57.05N    10.33E  1743    12
# 2                 NaN  Århus  Denmark   57.05N    10.33E  1744    01
# 3                 NaN  Århus  Denmark   57.05N    10.33E  1744    02
# 4                 NaN  Århus  Denmark   57.05N    10.33E  1744    03

# %%
def removeNaNRows(temperature, year):
    if temperature.isnull():
        df.drop([year])

# %%
df['new'] = df['Year']

# %%
df['Year' == 1743]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-d2c5b8542812> in <module>()
# ----> 1 df['Year' == 1743]
#
# /Users/al3x_hh/Documents/Uni/CLO/Proyecto/github/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Users/al3x_hh/Documents/Uni/CLO/Proyecto/github/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Users/al3x_hh/Documents/Uni/CLO/Proyecto/github/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Users/al3x_hh/Documents/Uni/CLO/Proyecto/github/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Users/al3x_hh/Documents/Uni/CLO/Proyecto/github/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False

# %%
df.head()
# Out:
#   AverageTemperature   City  Country Latitude Longitude  Year Month  \
# 0              6.068  Århus  Denmark   57.05N    10.33E  1743    11
# 1                nan  Århus  Denmark   57.05N    10.33E  1743    12
# 2                nan  Århus  Denmark   57.05N    10.33E  1744    01
# 3                nan  Århus  Denmark   57.05N    10.33E  1744    02
# 4                nan  Århus  Denmark   57.05N    10.33E  1744    03
#
#            new
# 0  1743, 6.068
# 1    1743, nan
# 2    1744, nan
# 3    1744, nan
# 4    1744, nan
